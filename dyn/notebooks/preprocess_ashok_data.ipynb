# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def get_cell(file_path):
    """ 
    Get the cell x-y coordinates for the cell in the file_path
    """
    # Step 2: Read the Image
    image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)

    # Step 3: Preprocess the Image
    blurred = cv2.GaussianBlur(image, (5, 5), 0)
    _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Step 4: Find Contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Step 5: Filter Contours
    min_area = 100
    cells_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]

    # Step 6: Draw Contours (optional)
    result = np.zeros_like(image)
    cv2.drawContours(result, cells_contours, -1, 255, 2)

    # Step 7: Get Coordinates
    cell_boundaries = []
    for contour in cells_contours:
        for point in contour:
            x, y = point[0]
            cell_boundaries.append((x, y))
    
    return np.array(cell_boundaries)

# %%
def get_line(file_path):
    file_name = file_path.split('/')[-1]
    line = None
    if '_A_' in file_name:
        line = file_name.split('_A_')[0]
    elif '_a_' in file_name:
        line = file_name.split('_a_')[0]
    elif '_B_' in file_name:
        line = file_name.split('_B_')[0]
    else:
        line = file_name.split('_b_')[0]
    return line.upper()

# %%
get_cell('/home/wanxinli/dyn/dyn/datasets/ashok_data/MDA_MB_231_A/MDA_MB_231_A_GDA_1_Cell4/MDA_MB_231_A_GDA_1_Cell4_ActinMask.bmp')
# Out:
# array([[504, 467],
#        [503, 468],
#        [501, 468],
#        [501, 469],
#        [502, 470],
#        [502, 476],
#        [501, 477],
#        [501, 478],
#        [498, 481],
#        [497, 480],
#        [495, 480],
#        [495, 481],
#        [494, 482],
#        [492, 482],
#        [492, 484],
#        [493, 485],
#        [493, 486],
#        [494, 487],
#        [494, 488],
#        [496, 490],
#        [496, 491],
#        [491, 496],
#        [491, 497],
#        [489, 499],
#        [489, 500],
#        [488, 501],
#        [488, 503],
#        [487, 504],
#        [487, 505],
#        [486, 506],
#        [486, 508],
#        [485, 509],
#        [484, 509],
#        [483, 510],
#        [483, 516],
#        [481, 518],
#        [479, 518],
#        [478, 517],
#        [477, 517],
#        [476, 518],
#        [476, 522],
#        [475, 523],
#        [474, 523],
#        [473, 524],
#        [473, 525],
#        [474, 526],
#        [474, 527],
#        [475, 528],
#        [475, 530],
#        [476, 531],
#        [476, 532],
#        [477, 533],
#        [477, 534],
#        [482, 539],
#        [483, 539],
#        [485, 541],
#        [488, 541],
#        [489, 542],
#        [490, 542],
#        [492, 544],
#        [493, 544],
#        [494, 545],
#        [495, 545],
#        [496, 546],
#        [500, 546],
#        [501, 547],
#        [502, 547],
#        [503, 548],
#        [505, 548],
#        [506, 549],
#        [508, 549],
#        [510, 547],
#        [512, 547],
#        [514, 545],
#        [515, 545],
#        [520, 540],
#        [521, 540],
#        [522, 539],
#        [522, 538],
#        [525, 535],
#        [526, 535],
#        [529, 532],
#        [534, 532],
#        [535, 533],
#        [538, 533],
#        [538, 532],
#        [536, 530],
#        [536, 529],
#        [538, 527],
#        [538, 526],
#        [536, 524],
#        [536, 523],
#        [538, 521],
#        [539, 521],
#        [539, 520],
#        [542, 517],
#        [543, 517],
#        [544, 516],
#        [544, 514],
#        [546, 512],
#        [547, 512],
#        [548, 511],
#        [549, 511],
#        [549, 510],
#        [548, 510],
#        [547, 509],
#        [547, 508],
#        [552, 503],
#        [553, 503],
#        [555, 501],
#        [556, 501],
#        [556, 499],
#        [554, 499],
#        [553, 500],
#        [552, 500],
#        [551, 501],
#        [548, 501],
#        [547, 500],
#        [547, 499],
#        [548, 498],
#        [548, 497],
#        [546, 497],
#        [545, 498],
#        [542, 498],
#        [541, 497],
#        [540, 497],
#        [537, 494],
#        [537, 493],
#        [536, 492],
#        [536, 489],
#        [532, 485],
#        [532, 480],
#        [530, 478],
#        [528, 478],
#        [527, 477],
#        [523, 477],
#        [522, 478],
#        [520, 478],
#        [519, 477],
#        [517, 479],
#        [515, 477],
#        [515, 476],
#        [514, 476],
#        [512, 478],
#        [511, 478],
#        [508, 475],
#        [508, 474],
#        [507, 473],
#        [507, 472],
#        [506, 471],
#        [506, 468],
#        [505, 467]], dtype=int32)

# %%
# get_line('/home/wanxinli/dyn/dyn/datasets/ashok_data/MDA_MB_231_A/MDA_MB_231_A_GDA_1_Cell4/MDA_MB_231_A_GDA_1_Cell4_ActinMask.bmp')
get_line('/home/wanxinli/dyn/dyn/datasets/ashok_data/MCF10A_B/MCF10A_B_GDA_17_Cell2/MCF10A_B_GDA_17_Cell2_ActinMask.bmp')
# Out:
# 'MCF10A'

# %%
'_A' in 'MDA_MB_231_A_GDA_1_Cell4/MDA_MB_231_A_GDA_1_Cell4_ActinMask.bmp'
# Out:
# True

# %%
def prepare_input():
    ashok_data_path = '/home/wanxinli/dyn/dyn/datasets/ashok_data'
    cell_path = os.path.join(ashok_data_path, "cells.txt")
    line_path = os.path.join(ashok_data_path, "lines.txt")
    for dir in os.listdir(ashok_data_path):
        if os.path.isdir(os.path.join(ashok_data_path, dir)):
            for sub_dir in os.listdir(os.path.join(ashok_data_path, dir)):
                if os.path.isdir(os.path.join(ashok_data_path, dir, sub_dir)):
                    file_name = sub_dir.split('/')[-1]+'_ActinMask.bmp'
                    file_path = os.path.join(ashok_data_path, dir, sub_dir, file_name)
                    if file_name == 'MCF10A_B_GDA_13_Cell3_ActinMask.bmp':
                        continue
                    print("file_name is:", file_name)
                    line = get_line(file_name)
                    with open(line_path, 'a') as file:
                        file.write(line + '\n')
                    cell = get_cell(file_path)
                    with open(cell_path, 'a') as file:
                        np.savetxt(file, cell, fmt='%i')
                        file.write('\n')

# %%
prepare_input()
# Out:
# file_name is: MCF10A_B_GDA_17_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_7_Cell9_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_7_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_13_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_9_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_21_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_11_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell18_ActinMask.bmp
# file_name is: MCF10A_B_GDA_9_Cell9_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell16_ActinMask.bmp
# file_name is: MCF10A_B_GDA_4_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_2_Cell7_ActinMask.bmp
# file_name is: MCF10A_B_GDA_19_Cell12_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_13_Cell7_ActinMask.bmp
# file_name is: MCF10A_B_GDA_14_Cell12_ActinMask.bmp
# file_name is: MCF10A_B_GDA_12_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell16_ActinMask.bmp
# file_name is: MCF10A_B_GDA_9_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_14_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_2_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_11_Cell12_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_18_Cell16_ActinMask.bmp
# file_name is: MCF10A_B_GDA_5_Cell7_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell18_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell12_ActinMask.bmp
# file_name is: MCF10A_B_GDA_23_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_2_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_17_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_17_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_6_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_12_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_24_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_21_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell14_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_15_Cell15_ActinMask.bmp
# file_name is: MCF10A_B_GDA_12_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell14_ActinMask.bmp
# file_name is: MCF10A_B_GDA_11_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_11_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell19_ActinMask.bmp
# file_name is: MCF10A_B_GDA_5_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_21_Cell9_ActinMask.bmp
# file_name is: MCF10A_B_GDA_17_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell7_ActinMask.bmp
# file_name is: MCF10A_B_GDA_19_Cell15_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_7_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_12_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_18_Cell15_ActinMask.bmp
# file_name is: MCF10A_B_GDA_6_Cell7_ActinMask.bmp
# file_name is: MCF10A_B_GDA_18_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_7_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell15_ActinMask.bmp
# file_name is: MCF10A_B_GDA_22_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_17_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_4_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_18_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_6_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell21_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell15_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_15_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_22_Cell24_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell14_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_14_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell17_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_6_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_21_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_13_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_1_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_13_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_15_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_18_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_18_Cell14_ActinMask.bmp
# file_name is: MCF10A_B_GDA_7_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_23_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell15_ActinMask.bmp
# file_name is: MCF10A_B_GDA_5_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_6_Cell8_ActinMask.bmp
# file_name is: MCF10A_B_GDA_9_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_22_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_5_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_5_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_17_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_17_Cell7_ActinMask.bmp
# file_name is: MCF10A_B_GDA_22_Cell25_ActinMask.bmp
# file_name is: MCF10A_B_GDA_19_Cell11_ActinMask.bmp
# file_name is: MCF10A_B_GDA_9_Cell12_ActinMask.bmp
# file_name is: MCF10A_B_GDA_23_Cell3_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell12_ActinMask.bmp
# file_name is: MCF10A_B_GDA_21_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_24_Cell6_ActinMask.bmp
# file_name is: MCF10A_B_GDA_24_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_16_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_20_Cell16_ActinMask.bmp
# file_name is: MCF10A_B_GDA_3_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_13_Cell1_ActinMask.bmp
# file_name is: MCF10A_B_GDA_8_Cell11_ActinMask.bmp
# file_name is: MCF10A_B_GDA_23_Cell2_ActinMask.bmp
# file_name is: MCF10A_B_GDA_13_Cell10_ActinMask.bmp
# file_name is: MCF10A_B_GDA_6_Cell4_ActinMask.bmp
# file_name is: MCF10A_B_GDA_14_Cell13_ActinMask.bmp
# file_name is: MCF10A_B_GDA_2_Cell11_ActinMask.bmp
# file_name is: MCF10A_B_GDA_10_Cell5_ActinMask.bmp
# file_name is: MCF10A_B_GDA_12_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_4_Cell11_ActinMask.bmp
# file_name is: MCF10A_A_GDA_19_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_21_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell10_ActinMask.bmp
# file_name is: MCF10A_A_GDA_18_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_19_Cell13_ActinMask.bmp
# file_name is: MCF10A_A_GDA_16_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_17_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_17_Cell11_ActinMask.bmp
# file_name is: MCF10A_A_GDA_4_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_5_Cell17_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell19_ActinMask.bmp
# file_name is: MCF10A_A_GDA_19_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_6_Cell12_ActinMask.bmp
# file_name is: MCF10A_A_GDA_4_Cell12_ActinMask.bmp
# file_name is: MCF10A_A_GDA_9_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_25_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_3_Cell12_ActinMask.bmp
# file_name is: MCF10A_A_GDA_27_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_24_Cell10_ActinMask.bmp
# file_name is: MCF10A_A_GDA_24_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_28_Cell13_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_6_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_9_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_26_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_24_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell14_ActinMask.bmp
# file_name is: MCF10A_A_GDA_22_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_21_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_17_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_28_Cell15_ActinMask.bmp
# file_name is: MCF10A_A_GDA_26_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_19_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_17_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_16_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_28_Cell11_ActinMask.bmp
# file_name is: MCF10A_A_GDA_27_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_1_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_21_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_18_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_6_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_23_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_19_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell11_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_7_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_27_Cell10_ActinMask.bmp
# file_name is: MCF10A_A_GDA_1_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell8_ActinMask.bmp
# file_name is: MCF10A_A_GDA_1_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_7_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_28_Cell17_ActinMask.bmp
# file_name is: MCF10A_A_GDA_25_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_21_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_26_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell15_ActinMask.bmp
# file_name is: MCF10A_A_GDA_9_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_4_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_5_Cell15_ActinMask.bmp
# file_name is: MCF10A_A_GDA_4_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_17_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_18_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_1_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_19_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_18_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_23_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_6_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_18_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_27_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_9_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_26_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_25_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell11_ActinMask.bmp
# file_name is: MCF10A_A_GDA_3_Cell10_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell7_ActinMask.bmp
# file_name is: MCF10A_A_GDA_7_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_24_Cell9_ActinMask.bmp
# file_name is: MCF10A_A_GDA_5_Cell14_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_28_Cell14_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_25_Cell8_ActinMask.bmp
# file_name is: MCF10A_A_GDA_20_Cell4_ActinMask.bmp
# file_name is: MCF10A_A_GDA_3_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_2_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_16_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_17_Cell10_ActinMask.bmp
# file_name is: MCF10A_A_GDA_3_Cell6_ActinMask.bmp
# file_name is: MCF10A_A_GDA_23_Cell2_ActinMask.bmp
# file_name is: MCF10A_A_GDA_26_Cell3_ActinMask.bmp
# file_name is: MCF10A_A_GDA_23_Cell12_ActinMask.bmp
# file_name is: MCF10A_A_GDA_8_Cell18_ActinMask.bmp
# file_name is: MCF10A_A_GDA_5_Cell16_ActinMask.bmp
# file_name is: MCF10A_A_GDA_3_Cell5_ActinMask.bmp
# file_name is: MCF10A_A_GDA_5_Cell1_ActinMask.bmp
# file_name is: MCF10A_A_GDA_18_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_11_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell21_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell1_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell25_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell30_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell25_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell19_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell20_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell23_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell22_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_7_Cell25_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell18_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell24_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_11_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell22_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_11_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell24_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell24_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell22_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_9_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell23_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_1_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell21_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell21_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_5_Cell18_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_11_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_6_Cell19_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_12_Cell1_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_11_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_10_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_4_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_2_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_8_Cell18_ActinMask.bmp
# file_name is: MDA_MB_231_B_GDA_3_Cell8_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell11_ActinMask.bmp
# file_name is: mcf7_b_gda_1_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_17_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_24_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_25_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_12_Cell12_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell11_ActinMask.bmp
# file_name is: mcf7_b_gda_15_Cell20_ActinMask.bmp
# file_name is: mcf7_b_gda_10_Cell8_ActinMask.bmp
# file_name is: mcf7_b_gda_17_Cell10_ActinMask.bmp
# file_name is: mcf7_b_gda_1_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_6_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_21_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_6_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_8_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell17_ActinMask.bmp
# file_name is: mcf7_b_gda_23_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_23_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_21_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_4_Cell8_ActinMask.bmp
# file_name is: mcf7_b_gda_13_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_22_Cell16_ActinMask.bmp
# file_name is: mcf7_b_gda_17_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell12_ActinMask.bmp
# file_name is: mcf7_b_gda_14_Cell10_ActinMask.bmp
# file_name is: mcf7_b_gda_22_Cell13_ActinMask.bmp
# file_name is: mcf7_b_gda_2_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_23_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_7_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_8_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_8_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_24_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_5_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_1_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_12_Cell15_ActinMask.bmp
# file_name is: mcf7_b_gda_2_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_15_Cell21_ActinMask.bmp
# file_name is: mcf7_b_gda_7_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell12_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell13_ActinMask.bmp
# file_name is: mcf7_b_gda_10_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_17_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_15_Cell12_ActinMask.bmp
# file_name is: mcf7_b_gda_4_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_23_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_14_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_7_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_8_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_2_Cell8_ActinMask.bmp
# file_name is: mcf7_b_gda_13_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_7_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_16_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_3_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_10_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_14_Cell11_ActinMask.bmp
# file_name is: mcf7_b_gda_22_Cell10_ActinMask.bmp
# file_name is: mcf7_b_gda_24_Cell10_ActinMask.bmp
# file_name is: mcf7_b_gda_2_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell8_ActinMask.bmp
# file_name is: mcf7_b_gda_9_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell10_ActinMask.bmp
# file_name is: mcf7_b_gda_9_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_8_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_5_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_12_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_12_Cell14_ActinMask.bmp
# file_name is: mcf7_b_gda_4_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_13_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_21_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_12_Cell11_ActinMask.bmp
# file_name is: mcf7_b_gda_24_Cell9_ActinMask.bmp
# file_name is: mcf7_b_gda_14_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell9_ActinMask.bmp
# file_name is: mcf7_b_gda_1_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_23_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_21_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_16_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_6_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_25_Cell17_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell13_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_24_Cell11_ActinMask.bmp
# file_name is: mcf7_b_gda_21_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_16_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_4_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_3_Cell4_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell9_ActinMask.bmp
# file_name is: mcf7_b_gda_17_Cell9_ActinMask.bmp
# file_name is: mcf7_b_gda_3_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_10_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_25_Cell12_ActinMask.bmp
# file_name is: mcf7_b_gda_9_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell11_ActinMask.bmp
# file_name is: mcf7_b_gda_18_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_7_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_15_Cell22_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell10_ActinMask.bmp
# file_name is: mcf7_b_gda_17_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_9_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_25_Cell13_ActinMask.bmp
# file_name is: mcf7_b_gda_24_Cell6_ActinMask.bmp
# file_name is: mcf7_b_gda_16_Cell7_ActinMask.bmp
# file_name is: mcf7_b_gda_4_Cell9_ActinMask.bmp
# file_name is: mcf7_b_gda_9_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_14_Cell9_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_26_Cell14_ActinMask.bmp
# file_name is: mcf7_b_gda_1_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_20_Cell5_ActinMask.bmp
# file_name is: mcf7_b_gda_15_Cell1_ActinMask.bmp
# file_name is: mcf7_b_gda_7_Cell3_ActinMask.bmp
# file_name is: mcf7_b_gda_12_Cell2_ActinMask.bmp
# file_name is: mcf7_b_gda_25_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell1_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_2_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_13_Cell19_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_16_Cell1_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_13_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_8_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_13_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_7_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_13_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_8_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell18_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell21_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_13_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_16_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_7_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_11_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell22_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_8_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_8_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_11_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_15_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell18_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_16_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell13_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_2_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_2_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell17_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_8_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell7_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell26_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_11_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_8_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell12_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell20_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell23_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_7_Cell8_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_7_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_11_Cell1_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell18_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell15_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_15_Cell6_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_10_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell27_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_12_Cell14_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_11_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_16_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell5_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_7_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell19_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_2_Cell3_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_11_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell20_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell4_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_1_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_2_Cell10_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_6_Cell11_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell2_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell16_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_5_Cell25_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_14_Cell9_ActinMask.bmp
# file_name is: MDA_MB_231_A_GDA_9_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_8_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_10_Cell11_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell13_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell14_ActinMask.bmp
# file_name is: mcf7_a_gda_20_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_5_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_1_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_14_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_18_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_18_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_18_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_2_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_18_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_2_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_20_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_1_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_20_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_6_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_9_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell11_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_17_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_8_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_11_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_18_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_2_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_5_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_14_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_9_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_11_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_6_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell12_ActinMask.bmp
# file_name is: mcf7_a_gda_20_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell11_ActinMask.bmp
# file_name is: mcf7_a_gda_4_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_17_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_2_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_20_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_1_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_9_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_11_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_12_Cell11_ActinMask.bmp
# file_name is: mcf7_a_gda_4_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_18_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_5_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_14_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_4_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_6_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell17_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_1_Cell13_ActinMask.bmp
# file_name is: mcf7_a_gda_14_Cell13_ActinMask.bmp
# file_name is: mcf7_a_gda_6_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_10_Cell13_ActinMask.bmp
# file_name is: mcf7_a_gda_4_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_17_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_12_Cell9_ActinMask.bmp
# file_name is: mcf7_a_gda_12_Cell10_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_14_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_4_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell15_ActinMask.bmp
# file_name is: mcf7_a_gda_1_Cell12_ActinMask.bmp
# file_name is: mcf7_a_gda_9_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_8_Cell10_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_12_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_8_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_7_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_5_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_10_Cell7_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell10_ActinMask.bmp
# file_name is: mcf7_a_gda_11_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_19_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_10_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_3_Cell1_ActinMask.bmp
# file_name is: mcf7_a_gda_15_Cell6_ActinMask.bmp
# file_name is: mcf7_a_gda_9_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_16_Cell8_ActinMask.bmp
# file_name is: mcf7_a_gda_3_Cell3_ActinMask.bmp
# file_name is: mcf7_a_gda_17_Cell5_ActinMask.bmp
# file_name is: mcf7_a_gda_20_Cell4_ActinMask.bmp
# file_name is: mcf7_a_gda_13_Cell2_ActinMask.bmp
# file_name is: mcf7_a_gda_9_Cell4_ActinMask.bmp
